# %%
# 必要なライブラリをimport
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# 可視化のためのセットです。
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

import sklearn
from sklearn.linear_model import LinearRegression

#現在の最大表示列数の出力
pd.get_option("display.max_columns")

#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)

# %%
# データフレーム読み込み
girls_frame = pd.read_clipboard()

# %%
girls_frame
# Out:
#       年度     所属球団   試合   打席   打数  得点   安打  二塁打  三塁打  本塁打   塁打  打点  盗塁  盗塁刺  \
# 0   2007  北海道日本ハム    7   11   11   1    1    0    0    0    1   0   1    0
# 1   2008  北海道日本ハム   63  205  188  19   45   14    1    5   76  21  13    3
# 2   2009  北海道日本ハム  131  496  425  74  130   40    3   15  221  58  24    6
# 3   2010  北海道日本ハム  138  583  488  86  151   33    3   15  235  64  26    8
# 4   2011  北海道日本ハム  137  578  489  72  156   30    0   11  219  54  31    6
# 5   2012  北海道日本ハム  134  597  510  72  155   21    3    9  209  48  22    9
# 6   2013    オリックス  141  601  524  75  157   33    2   17  245  61  33    9
# 7   2014    オリックス  140  590  502  73  166   36    2   19  263  81  31    9
# 8   2015    オリックス  132  565  484  61  127   22    0   17  200  68  11    4
# 9   2016    オリックス  143  616  532  79  163   24    1   17  240  70  53   17
# 10  2017      阪　神  114  493  427  60  124   16    0   17  191  62  21    6
# 11  2018      阪　神  119  509  419  60  129   24    0   16  201  68  22    3
# 12  2019      阪　神  103  444  382  45  120   22    1    5  159  42   9    5
# 13  2020      阪　神   37  139  117  13   27    6    0    1   36  11   2    1
#
#     犠打  犠飛  四球  死球  三振  併殺打     打率    長打率    出塁率
# 0    0   0   0   0   1    0  0.091  0.091  0.091
# 1    5   0  10   2  53    6  0.239  0.404  0.285
# 2   18   1  46   6  93    6  0.306  0.520  0.381
# 3   13   1  71  10  94    7  0.309  0.482  0.407
# 4    9   2  59  19  91    5  0.319  0.448  0.411
# 5    0   1  75  11  86    9  0.304  0.410  0.404
# 6    0   3  66   8  93    6  0.300  0.468  0.384
# 7    0   4  70  14  73    7  0.331  0.524  0.424
# 8    0   1  72   8  78   10  0.262  0.413  0.366
# 9    0   2  75   7  84   13  0.306  0.451  0.398
# 10   0   2  59   5  62   12  0.290  0.447  0.381
# 11   0   5  77   8  63    9  0.308  0.480  0.420
# 12   0   3  52   7  63   10  0.314  0.416  0.403
# 13   0   0  19   3  21    3  0.231  0.308  0.353
