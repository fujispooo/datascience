# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid', {'grid.linestyle': '--'})
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
from sklearn.preprocessing import add_dummy_feature

# %%
boston = load_boston()
type(boston)

# utils bunchとは何か
# Out:
# sklearn.utils.Bunch

# %%
print(boston.DESCR)

# DESCR はdescribe は「説明する」という動詞の略称
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
plt.hist(boston.target, bins=50)
plt.xlabel('Price ($1,000)')
plt.ylabel('Number of houses')

# target: 土地の価格
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
plt.scatter(boston.data[:,5], boston.target)
plt.ylabel('Price ($1,000)')
plt.xlabel('Number of romes')

# 散布図
# scatter(第一引数(説明変数),第二引数(目的変数))
# Out:
# Text(0.5, 0, 'Number of romes')

# %%
boston_df = pd.DataFrame(boston.data)
boston_df.columns = boston.feature_names
type(boston.data)
# Out:
# numpy.ndarray

# %%
boston.data[100]
# Out:
# array([1.4866e-01, 0.0000e+00, 8.5600e+00, 0.0000e+00, 5.2000e-01,
#        6.7270e+00, 7.9900e+01, 2.7778e+00, 5.0000e+00, 3.8400e+02,
#        2.0900e+01, 3.9476e+02, 9.4200e+00])

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df['Price'] = boston.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
sns.lmplot('RM','Price',data= boston_df) 

# 散布図と回帰直線

# %%
X = boston_df.RM

# %%
X.shape
X
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
X = np.vstack(X)
X.shape

# 二次元配列にしている(ライブラリの都合上)
# Out:
# (506, 1)

# %%
X
# Out:
# array([[6.575],
#        [6.421],
#        [7.185],
#        [6.998],
#        [7.147],
#        [6.43 ],
#        [6.012],
#        [6.172],
#        [5.631],
#        [6.004],
#        [6.377],
#        [6.009],
#        [5.889],
#        [5.949],
#        [6.096],
#        [5.834],
#        [5.935],
#        [5.99 ],
#        [5.456],
#        [5.727],
#        [5.57 ],
#        [5.965],
#        [6.142],
#        [5.813],
#        [5.924],
#        [5.599],
#        [5.813],
#        [6.047],
#        [6.495],
#        [6.674],
#        [5.713],
#        [6.072],
#        [5.95 ],
#        [5.701],
#        [6.096],
#        [5.933],
#        [5.841],
#        [5.85 ],
#        [5.966],
#        [6.595],
#        [7.024],
#        [6.77 ],
#        [6.169],
#        [6.211],
#        [6.069],
#        [5.682],
#        [5.786],
#        [6.03 ],
#        [5.399],
#        [5.602],
#        [5.963],
#        [6.115],
#        [6.511],
#        [5.998],
#        [5.888],
#        [7.249],
#        [6.383],
#        [6.816],
#        [6.145],
#        [5.927],
#        [5.741],
#        [5.966],
#        [6.456],
#        [6.762],
#        [7.104],
#        [6.29 ],
#        [5.787],
#        [5.878],
#        [5.594],
#        [5.885],
#        [6.417],
#        [5.961],
#        [6.065],
#        [6.245],
#        [6.273],
#        [6.286],
#        [6.279],
#        [6.14 ],
#        [6.232],
#        [5.874],
#        [6.727],
#        [6.619],
#        [6.302],
#        [6.167],
#        [6.389],
#        [6.63 ],
#        [6.015],
#        [6.121],
#        [7.007],
#        [7.079],
#        [6.417],
#        [6.405],
#        [6.442],
#        [6.211],
#        [6.249],
#        [6.625],
#        [6.163],
#        [8.069],
#        [7.82 ],
#        [7.416],
#        [6.727],
#        [6.781],
#        [6.405],
#        [6.137],
#        [6.167],
#        [5.851],
#        [5.836],
#        [6.127],
#        [6.474],
#        [6.229],
#        [6.195],
#        [6.715],
#        [5.913],
#        [6.092],
#        [6.254],
#        [5.928],
#        [6.176],
#        [6.021],
#        [5.872],
#        [5.731],
#        [5.87 ],
#        [6.004],
#        [5.961],
#        [5.856],
#        [5.879],
#        [5.986],
#        [5.613],
#        [5.693],
#        [6.431],
#        [5.637],
#        [6.458],
#        [6.326],
#        [6.372],
#        [5.822],
#        [5.757],
#        [6.335],
#        [5.942],
#        [6.454],
#        [5.857],
#        [6.151],
#        [6.174],
#        [5.019],
#        [5.403],
#        [5.468],
#        [4.903],
#        [6.13 ],
#        [5.628],
#        [4.926],
#        [5.186],
#        [5.597],
#        [6.122],
#        [5.404],
#        [5.012],
#        [5.709],
#        [6.129],
#        [6.152],
#        [5.272],
#        [6.943],
#        [6.066],
#        [6.51 ],
#        [6.25 ],
#        [7.489],
#        [7.802],
#        [8.375],
#        [5.854],
#        [6.101],
#        [7.929],
#        [5.877],
#        [6.319],
#        [6.402],
#        [5.875],
#        [5.88 ],
#        [5.572],
#        [6.416],
#        [5.859],
#        [6.546],
#        [6.02 ],
#        [6.315],
#        [6.86 ],
#        [6.98 ],
#        [7.765],
#        [6.144],
#        [7.155],
#        [6.563],
#        [5.604],
#        [6.153],
#        [7.831],
#        [6.782],
#        [6.556],
#        [7.185],
#        [6.951],
#        [6.739],
#        [7.178],
#        [6.8  ],
#        [6.604],
#        [7.875],
#        [7.287],
#        [7.107],
#        [7.274],
#        [6.975],
#        [7.135],
#        [6.162],
#        [7.61 ],
#        [7.853],
#        [8.034],
#        [5.891],
#        [6.326],
#        [5.783],
#        [6.064],
#        [5.344],
#        [5.96 ],
#        [5.404],
#        [5.807],
#        [6.375],
#        [5.412],
#        [6.182],
#        [5.888],
#        [6.642],
#        [5.951],
#        [6.373],
#        [6.951],
#        [6.164],
#        [6.879],
#        [6.618],
#        [8.266],
#        [8.725],
#        [8.04 ],
#        [7.163],
#        [7.686],
#        [6.552],
#        [5.981],
#        [7.412],
#        [8.337],
#        [8.247],
#        [6.726],
#        [6.086],
#        [6.631],
#        [7.358],
#        [6.481],
#        [6.606],
#        [6.897],
#        [6.095],
#        [6.358],
#        [6.393],
#        [5.593],
#        [5.605],
#        [6.108],
#        [6.226],
#        [6.433],
#        [6.718],
#        [6.487],
#        [6.438],
#        [6.957],
#        [8.259],
#        [6.108],
#        [5.876],
#        [7.454],
#        [8.704],
#        [7.333],
#        [6.842],
#        [7.203],
#        [7.52 ],
#        [8.398],
#        [7.327],
#        [7.206],
#        [5.56 ],
#        [7.014],
#        [8.297],
#        [7.47 ],
#        [5.92 ],
#        [5.856],
#        [6.24 ],
#        [6.538],
#        [7.691],
#        [6.758],
#        [6.854],
#        [7.267],
#        [6.826],
#        [6.482],
#        [6.812],
#        [7.82 ],
#        [6.968],
#        [7.645],
#        [7.923],
#        [7.088],
#        [6.453],
#        [6.23 ],
#        [6.209],
#        [6.315],
#        [6.565],
#        [6.861],
#        [7.148],
#        [6.63 ],
#        [6.127],
#        [6.009],
#        [6.678],
#        [6.549],
#        [5.79 ],
#        [6.345],
#        [7.041],
#        [6.871],
#        [6.59 ],
#        [6.495],
#        [6.982],
#        [7.236],
#        [6.616],
#        [7.42 ],
#        [6.849],
#        [6.635],
#        [5.972],
#        [4.973],
#        [6.122],
#        [6.023],
#        [6.266],
#        [6.567],
#        [5.705],
#        [5.914],
#        [5.782],
#        [6.382],
#        [6.113],
#        [6.426],
#        [6.376],
#        [6.041],
#        [5.708],
#        [6.415],
#        [6.431],
#        [6.312],
#        [6.083],
#        [5.868],
#        [6.333],
#        [6.144],
#        [5.706],
#        [6.031],
#        [6.316],
#        [6.31 ],
#        [6.037],
#        [5.869],
#        [5.895],
#        [6.059],
#        [5.985],
#        [5.968],
#        [7.241],
#        [6.54 ],
#        [6.696],
#        [6.874],
#        [6.014],
#        [5.898],
#        [6.516],
#        [6.635],
#        [6.939],
#        [6.49 ],
#        [6.579],
#        [5.884],
#        [6.728],
#        [5.663],
#        [5.936],
#        [6.212],
#        [6.395],
#        [6.127],
#        [6.112],
#        [6.398],
#        [6.251],
#        [5.362],
#        [5.803],
#        [8.78 ],
#        [3.561],
#        [4.963],
#        [3.863],
#        [4.97 ],
#        [6.683],
#        [7.016],
#        [6.216],
#        [5.875],
#        [4.906],
#        [4.138],
#        [7.313],
#        [6.649],
#        [6.794],
#        [6.38 ],
#        [6.223],
#        [6.968],
#        [6.545],
#        [5.536],
#        [5.52 ],
#        [4.368],
#        [5.277],
#        [4.652],
#        [5.   ],
#        [4.88 ],
#        [5.39 ],
#        [5.713],
#        [6.051],
#        [5.036],
#        [6.193],
#        [5.887],
#        [6.471],
#        [6.405],
#        [5.747],
#        [5.453],
#        [5.852],
#        [5.987],
#        [6.343],
#        [6.404],
#        [5.349],
#        [5.531],
#        [5.683],
#        [4.138],
#        [5.608],
#        [5.617],
#        [6.852],
#        [5.757],
#        [6.657],
#        [4.628],
#        [5.155],
#        [4.519],
#        [6.434],
#        [6.782],
#        [5.304],
#        [5.957],
#        [6.824],
#        [6.411],
#        [6.006],
#        [5.648],
#        [6.103],
#        [5.565],
#        [5.896],
#        [5.837],
#        [6.202],
#        [6.193],
#        [6.38 ],
#        [6.348],
#        [6.833],
#        [6.425],
#        [6.436],
#        [6.208],
#        [6.629],
#        [6.461],
#        [6.152],
#        [5.935],
#        [5.627],
#        [5.818],
#        [6.406],
#        [6.219],
#        [6.485],
#        [5.854],
#        [6.459],
#        [6.341],
#        [6.251],
#        [6.185],
#        [6.417],
#        [6.749],
#        [6.655],
#        [6.297],
#        [7.393],
#        [6.728],
#        [6.525],
#        [5.976],
#        [5.936],
#        [6.301],
#        [6.081],
#        [6.701],
#        [6.376],
#        [6.317],
#        [6.513],
#        [6.209],
#        [5.759],
#        [5.952],
#        [6.003],
#        [5.926],
#        [5.713],
#        [6.167],
#        [6.229],
#        [6.437],
#        [6.98 ],
#        [5.427],
#        [6.162],
#        [6.484],
#        [5.304],
#        [6.185],
#        [6.229],
#        [6.242],
#        [6.75 ],
#        [7.061],
#        [5.762],
#        [5.871],
#        [6.312],
#        [6.114],
#        [5.905],
#        [5.454],
#        [5.414],
#        [5.093],
#        [5.983],
#        [5.983],
#        [5.707],
#        [5.926],
#        [5.67 ],
#        [5.39 ],
#        [5.794],
#        [6.019],
#        [5.569],
#        [6.027],
#        [6.593],
#        [6.12 ],
#        [6.976],
#        [6.794],
#        [6.03 ]])

# %%
Y = boston_df.Price

# %%
# array([[array(),1]...]) => だめ
x1 = np.array([[value,1] for value in X])
x1
# array([[定数,1]...])　=> OK
x2 = add_dummy_feature(X)
x2
# array([[array(),1]...])　=> だめ
x3 = [[value,1] for value in X]
x3= np.array(x3)
x3
# array([[定数,1]...]) => OK
x4 = np.array([[value[0],1] for value in X])
x4
# Out:
# array([[6.575, 1.   ],
#        [6.421, 1.   ],
#        [7.185, 1.   ],
#        ...,
#        [6.976, 1.   ],
#        [6.794, 1.   ],
#        [6.03 , 1.   ]])

# %%
X = np.array([[value[0],1] for value in X])
X
# Out:
# array([[6.575, 1.   ],
#        [6.421, 1.   ],
#        [7.185, 1.   ],
#        ...,
#        [6.976, 1.   ],
#        [6.794, 1.   ],
#        [6.03 , 1.   ]])

# %%
a,b  = np.linalg.lstsq(X,Y)[0]
# Out:
# /Users/fujiiryou/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(boston_df.RM,boston_df.Price,'o')

x = boston_df.RM
plt.plot(x, a*x+b,'r')

print('回帰直線は目的変数Priceに対し,説明変数RMを用いて y={}x+{}と表せる'.format(a,b))
# Out:
# 回帰直線は目的変数Priceに対し,説明変数RMを用いて y=9.102108981180315x+-34.670620776438575と表せる

# %%
result = np.linalg.lstsq(X,Y)
# Out:
# /Users/fujiiryou/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
result

# 回帰直線の係数　と　切片
# 分散
#
# Out:
# (array([  9.10210898, -34.67062078]),
#  array([22061.87919621]),
#  2,
#  array([143.99484122,   2.46656609]))

# %%
error_total = result[1]
rmse = np.sqrt(error_total/len(X))

# %%
print('平均二乗誤差の平方根={:0.2f}'.format(rmse[0]))
# Out:
# 平均二乗誤差の平方根=6.60

# %% [markdown]
# ## 重回帰分析

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
X_multi2 = boston_df.drop('Price',axis=1)

# %%
X_multi = boston_df.drop('Price',1)
# Priceというカラムを削除する
# 第二引数の1は列方向を指定している,デフォルトでは行方向

# %%
X_multi
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
X_multi.shape
# 説明変数が13個
# Out:
# (506, 13)

# %%
Y_target = boston_df.Price

# %%
lreg.fit(X_multi,Y_target)

# 目的変数に対して、説明変数をぶち込んでいる
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lreg.intercept_
#切片
# Out:
# 36.45948838508978

# %%
import inspect

for method in inspect.getmembers(lreg):
    print(method)
# Out:
# ('__abstractmethods__', frozenset())
# ('__class__', <class 'sklearn.linear_model.base.LinearRegression'>)
# ('__delattr__', <method-wrapper '__delattr__' of LinearRegression object at 0x11905b210>)
# ('__dict__', {'fit_intercept': True, 'normalize': False, 'copy_X': True, 'n_jobs': None, 'coef_': array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#        -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#         3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#        -5.24758378e-01]), '_residues': 11078.784577954977, 'rank_': 13, 'singular_': array([3.94960823e+03, 1.77663071e+03, 6.42863748e+02, 3.66982075e+02,
#        1.58634553e+02, 1.18649824e+02, 9.00666968e+01, 6.93635022e+01,
#        4.06575034e+01, 2.44208029e+01, 1.13513722e+01, 5.50905795e+00,
#        1.24197449e+00]), 'intercept_': 36.45948838508978})
# ('__dir__', <built-in method __dir__ of LinearRegression object at 0x11905b210>)
# ('__doc__', '\n    Ordinary least squares Linear Regression.\n\n    Parameters\n    ----------\n    fit_intercept : boolean, optional, default True\n        whether to calculate the intercept for this model. If set\n        to False, no intercept will be used in calculations\n        (e.g. data is expected to be already centered).\n\n    normalize : boolean, optional, default False\n        This parameter is ignored when ``fit_intercept`` is set to False.\n        If True, the regressors X will be normalized before regression by\n        subtracting the mean and dividing by the l2-norm.\n        If you wish to standardize, please use\n        :class:`sklearn.preprocessing.StandardScaler` before calling ``fit`` on\n        an estimator with ``normalize=False``.\n\n    copy_X : boolean, optional, default True\n        If True, X will be copied; else, it may be overwritten.\n\n    n_jobs : int or None, optional (default=None)\n        The number of jobs to use for the computation. This will only provide\n        speedup for n_targets > 1 and sufficient large problems.\n        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.\n        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`\n        for more details.\n\n    Attributes\n    ----------\n    coef_ : array, shape (n_features, ) or (n_targets, n_features)\n        Estimated coefficients for the linear regression problem.\n        If multiple targets are passed during the fit (y 2D), this\n        is a 2D array of shape (n_targets, n_features), while if only\n        one target is passed, this is a 1D array of length n_features.\n\n    intercept_ : array\n        Independent term in the linear model.\n\n    Examples\n    --------\n    >>> import numpy as np\n    >>> from sklearn.linear_model import LinearRegression\n    >>> X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])\n    >>> # y = 1 * x_0 + 2 * x_1 + 3\n    >>> y = np.dot(X, np.array([1, 2])) + 3\n    >>> reg = LinearRegression().fit(X, y)\n    >>> reg.score(X, y)\n    1.0\n    >>> reg.coef_\n    array([1., 2.])\n    >>> reg.intercept_ # doctest: +ELLIPSIS\n    3.0000...\n    >>> reg.predict(np.array([[3, 5]]))\n    array([16.])\n\n    Notes\n    -----\n    From the implementation point of view, this is just plain Ordinary\n    Least Squares (scipy.linalg.lstsq) wrapped as a predictor object.\n\n    ')
# ('__eq__', <method-wrapper '__eq__' of LinearRegression object at 0x11905b210>)
# ('__format__', <built-in method __format__ of LinearRegression object at 0x11905b210>)
# ('__ge__', <method-wrapper '__ge__' of LinearRegression object at 0x11905b210>)
# ('__getattribute__', <method-wrapper '__getattribute__' of LinearRegression object at 0x11905b210>)
# ('__getstate__', <bound method BaseEstimator.__getstate__ of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('__gt__', <method-wrapper '__gt__' of LinearRegression object at 0x11905b210>)
# ('__hash__', <method-wrapper '__hash__' of LinearRegression object at 0x11905b210>)
# ('__init__', <bound method LinearRegression.__init__ of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('__init_subclass__', <built-in method __init_subclass__ of ABCMeta object at 0x7fa29c6c90c0>)
# ('__le__', <method-wrapper '__le__' of LinearRegression object at 0x11905b210>)
# ('__lt__', <method-wrapper '__lt__' of LinearRegression object at 0x11905b210>)
# ('__module__', 'sklearn.linear_model.base')
# ('__ne__', <method-wrapper '__ne__' of LinearRegression object at 0x11905b210>)
# ('__new__', <built-in method __new__ of type object at 0x102567560>)
# ('__reduce__', <built-in method __reduce__ of LinearRegression object at 0x11905b210>)
# ('__reduce_ex__', <built-in method __reduce_ex__ of LinearRegression object at 0x11905b210>)
# ('__repr__', <bound method BaseEstimator.__repr__ of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('__setattr__', <method-wrapper '__setattr__' of LinearRegression object at 0x11905b210>)
# ('__setstate__', <bound method BaseEstimator.__setstate__ of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('__sizeof__', <built-in method __sizeof__ of LinearRegression object at 0x11905b210>)
# ('__str__', <method-wrapper '__str__' of LinearRegression object at 0x11905b210>)
# ('__subclasshook__', <built-in method __subclasshook__ of ABCMeta object at 0x7fa29c6c90c0>)
# ('__weakref__', None)
# ('_abc_impl', <_abc_data object at 0x118b4c450>)
# ('_decision_function', <bound method LinearModel._decision_function of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('_estimator_type', 'regressor')
# ('_get_param_names', <bound method BaseEstimator._get_param_names of <class 'sklearn.linear_model.base.LinearRegression'>>)
# ('_get_tags', <bound method BaseEstimator._get_tags of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('_more_tags', <bound method MultiOutputMixin._more_tags of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('_preprocess_data', <function _preprocess_data at 0x118c12830>)
# ('_residues', 11078.784577954977)
# ('_set_intercept', <bound method LinearModel._set_intercept of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('coef_', array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#        -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#         3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#        -5.24758378e-01]))
# ('copy_X', True)
# ('fit', <bound method LinearRegression.fit of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('fit_intercept', True)
# ('get_params', <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('intercept_', 36.45948838508978)
# ('n_jobs', None)
# ('normalize', False)
# ('predict', <bound method LinearModel.predict of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('rank_', 13)
# ('score', <bound method RegressorMixin.score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('set_params', <bound method BaseEstimator.set_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>)
# ('singular_', array([3.94960823e+03, 1.77663071e+03, 6.42863748e+02, 3.66982075e+02,
#        1.58634553e+02, 1.18649824e+02, 9.00666968e+01, 6.93635022e+01,
#        4.06575034e+01, 2.44208029e+01, 1.13513722e+01, 5.50905795e+00,
#        1.24197449e+00]))

# %%
len(lreg.coef_)
# Out:
# 13

# %%
coeff_df = DataFrame(boston_df.columns)
coeff_df
# Out:
#           0
# 0      CRIM
# 1        ZN
# 2     INDUS
# 3      CHAS
# 4       NOX
# 5        RM
# 6       AGE
# 7       DIS
# 8       RAD
# 9       TAX
# 10  PTRATIO
# 11        B
# 12    LSTAT
# 13    Price

# %%
coeff_df.columns = ['Features']
coeff_df
# Out:
#    Features
# 0      CRIM
# 1        ZN
# 2     INDUS
# 3      CHAS
# 4       NOX
# 5        RM
# 6       AGE
# 7       DIS
# 8       RAD
# 9       TAX
# 10  PTRATIO
# 11        B
# 12    LSTAT
# 13    Price

# %%
coeff_df['Coefficent Estimate'] =  pd.Series(lreg.coef_)
coeff_df
# Out:
#    Features  Coefficent Estimate
# 0      CRIM            -0.108011
# 1        ZN             0.046420
# 2     INDUS             0.020559
# 3      CHAS             2.686734
# 4       NOX           -17.766611
# 5        RM             3.809865
# 6       AGE             0.000692
# 7       DIS            -1.475567
# 8       RAD             0.306049
# 9       TAX            -0.012335
# 10  PTRATIO            -0.952747
# 11        B             0.009312
# 12    LSTAT            -0.524758
# 13    Price                  NaN

# %%
# モデルを作るためのサンプルと予測するためのサンプルに分ける
# cross validation
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X_multi,boston_df.Price)

# %%
print(X_train.shape , X_test.shape , Y_train.shape , Y_test.shape)
# Out:
# (379, 13) (127, 13) (379,) (127,)

# %%
lreg = LinearRegression()

# %%
lreg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_train = lreg.predict(X_train)

# %%
pred_test = lreg.predict(X_test)

# %%
np.mean((Y_train - pred_train)**2)
# Out:
# 22.524566490556843

# %%
np.mean((Y_test - pred_test)**2)
# Out:
# 20.519236368749546

# %%
train = plt.scatter(pred_train, (pred_train-Y_train), c='b',alpha=0.5)
test = plt.scatter(pred_test,(pred_test-Y_test),c='r',alpha=0.5)
plt.hlines(y=0, xmin=1.0,xmax= 50)

plt.legend((train,test),('Training','Test'), loc='lower left')
plt.title('Residual plots')
# Out:
# Text(0.5, 1.0, 'Residual plots')
